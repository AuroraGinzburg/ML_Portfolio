# %% [markdown]
# # Notebook 2: Exploratory Data Analysis and Data Cleaning

# %% [markdown]
# ## 2.1 Energy Demand Exploratory Data Analysis

# %%
#imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from datetime import datetime

# %%
df = pd.read_csv('df.csv', index_col=0)

# %%
df.head(10)
# Out:
#          Date  Daily Energy Demand  Max Temp         Station ID  \
# 0  2018-04-10            7183786.0      79.0  GHCND:USW00023174
# 1  2018-04-10            7183786.0      85.0  GHCND:USW00023188
# 2  2018-04-10            7183786.0      63.0  GHCND:USW00023272
# 3  2018-04-10            7183786.0      86.0  GHCND:USW00093193
# 4  2018-04-10            7183786.0      68.0  GHCND:USW00093225
# 5  2018-04-10            7183786.0      69.0  GHCND:USW00023293
# 6  2018-04-10            7183786.0      72.0  GHCND:USW00003102
# 7  2018-04-11            1961585.0      74.0  GHCND:USW00023174
# 8  2018-04-11            1961585.0      73.0  GHCND:USW00023188
# 9  2018-04-11            1961585.0      60.0  GHCND:USW00023272
#
#                     Station Location  Min Temp
# 0  Los Angeles International Airport      60.0
# 1                  San Diego Airport      60.0
# 2             San Francisco Downtown      52.0
# 3      FRESNO YOSEMITE INTERNATIONAL      59.0
# 4    SACRAMENTO METROPOLITAN AIRPORT      51.0
# 5                           San Jose      52.0
# 6                    Ontario Airport      51.0
# 7  Los Angeles International Airport      57.0
# 8                  San Diego Airport      60.0
# 9             San Francisco Downtown      49.0

# %%
import seaborn as sns

# %%
plt.figure(figsize=(18,8))
plt.xticks(np.arange(0, len(df), 150))
sns.lineplot( x ='Date', y= 'Daily Energy Demand', data = df) 
plt.title("Fig. 2.1: California's Daily Energy Demand (2018-2022)", fontsize=18)
# Out:
# Text(0.5, 1.0, "Fig. 2.1: California's Daily Energy Demand (2018-2022)")

# %% [markdown]
# Some general trends can be seen each year, there is an annual spike that begins around July, and energy demand in January is low, comparatively.
# This initial plot affirms that the seasons will be an important factor in determining energy demand. This project will consider the effect of seasonality using weather data.

# %%
plt.figure(figsize=(15,6))
sns.lineplot( x ='Date', y= 'Daily Energy Demand', data = df.iloc[1280:1379]) #7*14 = 98 rows for a two week period
plt.xticks(np.arange(0, 14, 2))
plt.title("Fig. 2.2: Daily Energy Demand Over a Two Week Period in October 2018", fontsize=18)
plt.rc('axes', labelsize=14)
plt.rc('xtick', labelsize=10)
plt.rc('ytick', labelsize=10)

# %% [markdown]
# Looking at a random two week period, there are two dips, suggests the day of the week is potentially important. Let's create a feature for day of the week.

# %% [markdown]
# #### Feature Engineering- Day

# %%
df['Date']=pd.to_datetime((df['Date'])) #convert object type to DateTime

# %%
df['Date']
# Out:
# 0       2018-04-10
# 1       2018-04-10
# 2       2018-04-10
# 3       2018-04-10
# 4       2018-04-10
#            ...
# 10467   2022-05-15
# 10468   2022-05-16
# 10469   2022-05-16
# 10470   2022-05-16
# 10471   2022-05-16
# Name: Date, Length: 10472, dtype: datetime64[ns]

# %%
df['Day']= df['Date'].dt.day_name() #DateTime attribute

# %%
df.head(15)
# Out:
#          Date  Daily Energy Demand  Max Temp         Station ID  \
# 0  2018-04-10            7183786.0      79.0  GHCND:USW00023174
# 1  2018-04-10            7183786.0      85.0  GHCND:USW00023188
# 2  2018-04-10            7183786.0      63.0  GHCND:USW00023272
# 3  2018-04-10            7183786.0      86.0  GHCND:USW00093193
# 4  2018-04-10            7183786.0      68.0  GHCND:USW00093225
# 5  2018-04-10            7183786.0      69.0  GHCND:USW00023293
# 6  2018-04-10            7183786.0      72.0  GHCND:USW00003102
# 7  2018-04-11            1961585.0      74.0  GHCND:USW00023174
# 8  2018-04-11            1961585.0      73.0  GHCND:USW00023188
# 9  2018-04-11            1961585.0      60.0  GHCND:USW00023272
# 10 2018-04-11            1961585.0      75.0  GHCND:USW00093193
# 11 2018-04-11            1961585.0      62.0  GHCND:USW00093225
# 12 2018-04-11            1961585.0      68.0  GHCND:USW00023293
# 13 2018-04-11            1961585.0      82.0  GHCND:USW00003102
# 14 2018-04-12            6670701.0      68.0  GHCND:USW00023174
#
#                      Station Location  Min Temp        Day
# 0   Los Angeles International Airport      60.0    Tuesday
# 1                   San Diego Airport      60.0    Tuesday
# 2              San Francisco Downtown      52.0    Tuesday
# 3       FRESNO YOSEMITE INTERNATIONAL      59.0    Tuesday
# 4     SACRAMENTO METROPOLITAN AIRPORT      51.0    Tuesday
# 5                            San Jose      52.0    Tuesday
# 6                     Ontario Airport      51.0    Tuesday
# 7   Los Angeles International Airport      57.0  Wednesday
# 8                   San Diego Airport      60.0  Wednesday
# 9              San Francisco Downtown      49.0  Wednesday
# 10      FRESNO YOSEMITE INTERNATIONAL      51.0  Wednesday
# 11    SACRAMENTO METROPOLITAN AIRPORT      44.0  Wednesday
# 12                           San Jose      46.0  Wednesday
# 13                    Ontario Airport      46.0  Wednesday
# 14  Los Angeles International Airport      55.0   Thursday

# %%
#specify the order of the week to set the x-axis order for plotting
dayorder= ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']

# %%
plt.figure(figsize=(12,6))
sns.boxplot(data = df, x= 'Day', y='Daily Energy Demand', order=dayorder)
plt.title("Fig. 2.3: Average Energy Demand per Day of Week (2018-2022)", fontsize=18, pad=20)
plt.rc('axes', labelsize=14)
plt.rc('xtick', labelsize=10)
plt.rc('ytick', labelsize=10)

# %% [markdown]
#  Looks like the day of the week will be an important feature when forecasting energy demand. Energy demand is fairly consistent Tuesdays-Thursdays, with a slight decrease on Fridays and Mondays, and then a more substantial decrease on Saturdays and Sundays. Perhaps holiday weekends play a role in affecting Monday and Friday demand.

# %%
df.groupby('Day')['Daily Energy Demand'].describe()
# Out:
#             count          mean           std        min        25%  \
# Day
# Friday     1496.0  7.324006e+06  1.005175e+06  5761548.0  6655160.0
# Monday     1493.0  7.277122e+06  9.779865e+05  5474429.0  6638385.0
# Saturday   1497.0  6.826309e+06  9.854862e+05  5324575.0  6164517.0
# Sunday     1496.0  6.580411e+06  9.620885e+05  5242117.0  5898583.0
# Thursday   1498.0  7.397112e+06  9.748787e+05  5803203.0  6731143.0
# Tuesday    1496.0  7.387398e+06  9.867186e+05  5764182.0  6671303.0
# Wednesday  1496.0  7.388496e+06  1.053059e+06  1961585.0  6711839.0
#
#                  50%        75%         max
# Day
# Friday     6954462.5  7825330.0  10191567.0
# Monday     6917822.0  7881279.0  10409795.0
# Saturday   6450674.0  7259572.0  10157171.0
# Sunday     6229611.0  7130954.0  10171423.0
# Thursday   7011809.5  8051625.0  10200932.0
# Tuesday    7023464.0  7993980.0  10766451.0
# Wednesday  7024951.0  8029561.0  10617482.0

# %% [markdown]
# The statistics above are used to calculate the values in the boxplot. Note that the std is high for Fridays, further suggesting holiday weekends may cause fluctuation in demand.

# %% [markdown]
# ## 2.2 Data Cleaning
#
# We know that when scraping the energy data a few dates had incomplete data sets, this is clearly visible by the dip in Figure 2.1, and likely responsible for the outlying data point on a Wednesday in Figure 2.3. For the weather data, a few dates had missing temperature readings, so those will have to be dealt with.

# %% [markdown]
# Let's try using zscore to examine outlying energy values. This strategy will help to identify any days where there were less values being summed than expected.

# %%
from scipy.stats import zscore
from scipy import stats

# %%
z_scores = stats.zscore(df['Daily Energy Demand'])
abs_z_scores = np.abs(z_scores)
abs_z_scores.count()
# Out:
# 10472

# %%
outliers = abs_z_scores[abs_z_scores > 3]
outliers.count()
# Out:
# 42

# %% [markdown]
# Within the 10472 energy values, 42 of them were determined to have an absolute z score of > 3. It is important to mention that there are not 10472 days in the energy data set, there are 1498 days, but most of those days have 7 station's temperature readings for them so they occur 7x in the data set. So really, 6 days are outliers.

# %%
outliers_index = outliers.index.values

# %%
outliers_index
# Out:
# array([   7,    8,    9,   10,   11,   12,   13,  735,  736,  737,  738,
#         739,  740,  741,  742,  743,  744,  745,  746,  747,  748, 6011,
#        6012, 6013, 6014, 6015, 6016, 6017, 6018, 6019, 6020, 6021, 6022,
#        6023, 6024, 6025, 6026, 6027, 6028, 6029, 6030, 6031], dtype=int64)

# %% [markdown]
# The outliers have the index values written above.

# %% [markdown]
# It looks like April 11 is indeed incomplet

# %%
df.iloc[[ 7,    8,    9,   10,   11,   12,   13,  735,  736,  737,  738,
        739,  740,  741,  742,  743,  744,  745,  746,  747,  748, 6011,
       6012, 6013, 6014, 6015, 6016, 6017, 6018, 6019, 6020, 6021, 6022,
       6023, 6024, 6025, 6026, 6027, 6028, 6029, 6030, 6031]]
# Out:
#            Date  Daily Energy Demand  Max Temp         Station ID  \
# 7    2018-04-11            1961585.0      74.0  GHCND:USW00023174
# 8    2018-04-11            1961585.0      73.0  GHCND:USW00023188
# 9    2018-04-11            1961585.0      60.0  GHCND:USW00023272
# 10   2018-04-11            1961585.0      75.0  GHCND:USW00093193
# 11   2018-04-11            1961585.0      62.0  GHCND:USW00093225
# 12   2018-04-11            1961585.0      68.0  GHCND:USW00023293
# 13   2018-04-11            1961585.0      82.0  GHCND:USW00003102
# 735  2018-07-24           10471762.0      85.0  GHCND:USW00023174
# 736  2018-07-24           10471762.0      85.0  GHCND:USW00023188
# 737  2018-07-24           10471762.0      65.0  GHCND:USW00023272
# 738  2018-07-24           10471762.0     106.0  GHCND:USW00093193
# 739  2018-07-24           10471762.0     101.0  GHCND:USW00093225
# 740  2018-07-24           10471762.0      83.0  GHCND:USW00023293
# 741  2018-07-24           10471762.0      99.0  GHCND:USW00003102
# 742  2018-07-25           10482535.0      78.0  GHCND:USW00023174
# 743  2018-07-25           10482535.0      79.0  GHCND:USW00023188
# 744  2018-07-25           10482535.0      64.0  GHCND:USW00023272
# 745  2018-07-25           10482535.0     104.0  GHCND:USW00093193
# 746  2018-07-25           10482535.0     104.0  GHCND:USW00093225
# 747  2018-07-25           10482535.0      91.0  GHCND:USW00023293
# 748  2018-07-25           10482535.0     101.0  GHCND:USW00003102
# 6011 2020-08-17           10409795.0      78.0  GHCND:USW00023174
# 6012 2020-08-17           10409795.0      83.0  GHCND:USW00023188
# 6013 2020-08-17           10409795.0      81.0  GHCND:USW00023272
# 6014 2020-08-17           10409795.0     108.0  GHCND:USW00093193
# 6015 2020-08-17           10409795.0     101.0  GHCND:USW00093225
# 6016 2020-08-17           10409795.0      91.0  GHCND:USW00023293
# 6017 2020-08-17           10409795.0     107.0  GHCND:USW00003102
# 6018 2020-08-18           10766451.0      85.0  GHCND:USW00023174
# 6019 2020-08-18           10766451.0      83.0  GHCND:USW00023188
# 6020 2020-08-18           10766451.0      77.0  GHCND:USW00023272
# 6021 2020-08-18           10766451.0     107.0  GHCND:USW00093193
# 6022 2020-08-18           10766451.0     104.0  GHCND:USW00093225
# 6023 2020-08-18           10766451.0      85.0  GHCND:USW00023293
# 6024 2020-08-18           10766451.0     104.0  GHCND:USW00003102
# 6025 2020-08-19           10617482.0      85.0  GHCND:USW00023174
# 6026 2020-08-19           10617482.0      82.0  GHCND:USW00023188
# 6027 2020-08-19           10617482.0      77.0  GHCND:USW00023272
# 6028 2020-08-19           10617482.0     102.0  GHCND:USW00093193
# 6029 2020-08-19           10617482.0      99.0  GHCND:USW00093225
# 6030 2020-08-19           10617482.0      89.0  GHCND:USW00023293
# 6031 2020-08-19           10617482.0     103.0  GHCND:USW00003102
#
#                        Station Location  Min Temp        Day
# 7     Los Angeles International Airport      57.0  Wednesday
# 8                     San Diego Airport      60.0  Wednesday
# 9                San Francisco Downtown      49.0  Wednesday
# 10        FRESNO YOSEMITE INTERNATIONAL      51.0  Wednesday
# 11      SACRAMENTO METROPOLITAN AIRPORT      44.0  Wednesday
# 12                             San Jose      46.0  Wednesday
# 13                      Ontario Airport      46.0  Wednesday
# 735   Los Angeles International Airport      69.0    Tuesday
# 736                   San Diego Airport      71.0    Tuesday
# 737              San Francisco Downtown      56.0    Tuesday
# 738       FRESNO YOSEMITE INTERNATIONAL      75.0    Tuesday
# 739     SACRAMENTO METROPOLITAN AIRPORT      62.0    Tuesday
# 740                            San Jose      60.0    Tuesday
# 741                     Ontario Airport      71.0    Tuesday
# 742   Los Angeles International Airport      70.0  Wednesday
# 743                   San Diego Airport      70.0  Wednesday
# 744              San Francisco Downtown      55.0  Wednesday
# 745       FRESNO YOSEMITE INTERNATIONAL      75.0  Wednesday
# 746     SACRAMENTO METROPOLITAN AIRPORT      63.0  Wednesday
# 747                            San Jose      63.0  Wednesday
# 748                     Ontario Airport      67.0  Wednesday
# 6011  Los Angeles International Airport      67.0     Monday
# 6012                  San Diego Airport      71.0     Monday
# 6013             San Francisco Downtown      62.0     Monday
# 6014      FRESNO YOSEMITE INTERNATIONAL      81.0     Monday
# 6015    SACRAMENTO METROPOLITAN AIRPORT      76.0     Monday
# 6016                           San Jose      68.0     Monday
# 6017                    Ontario Airport      60.0     Monday
# 6018  Los Angeles International Airport      69.0    Tuesday
# 6019                  San Diego Airport      72.0    Tuesday
# 6020             San Francisco Downtown      61.0    Tuesday
# 6021      FRESNO YOSEMITE INTERNATIONAL      81.0    Tuesday
# 6022    SACRAMENTO METROPOLITAN AIRPORT      69.0    Tuesday
# 6023                           San Jose      60.0    Tuesday
# 6024                    Ontario Airport      75.0    Tuesday
# 6025  Los Angeles International Airport      73.0  Wednesday
# 6026                  San Diego Airport      72.0  Wednesday
# 6027             San Francisco Downtown      60.0  Wednesday
# 6028      FRESNO YOSEMITE INTERNATIONAL      82.0  Wednesday
# 6029    SACRAMENTO METROPOLITAN AIRPORT      72.0  Wednesday
# 6030                           San Jose      61.0  Wednesday
# 6031                    Ontario Airport      74.0  Wednesday

# %% [markdown]
# The above dates are the 6 days where the energy demand has a z score >3. Manual inspection of these dates on the Caiso website shows only 4/11 has incomplete data. It is likely that an atypical event caused higher than usual energy demand for Jul 24-25, 2018 and Aug 17-19, 2020. These events may have been heat waves, since the max temps were above 100 in some locations on those days.
#
# To account for the missing data on April 11, 2018, an average energy from the day before and day after will be used to replace the current value.

# %%
#average of April 10 and April 12 energy in 2018
(df.loc[df['Date']== '2018-04-10']['Daily Energy Demand'].values[0] + df.loc[df['Date']== '2018-04-12']['Daily Energy Demand'].values[0])/2
# Out:
# 6927243.5

# %%
#function for filling in the April 11 data
def missingdata_fill(row):
    if str(row['Date']) == '2018-04-11 00:00:00':
        energy= 6927243.5
        return energy
    else:
        return row['Daily Energy Demand']

# %%
df['Daily Energy Demand']= testdf.apply(missingdata_fill, axis=1)

# %%
df.head(20)
# Out:
#          Date  Daily Energy Demand  Max Temp         Station ID  \
# 0  2018-04-10            7183786.0      79.0  GHCND:USW00023174
# 1  2018-04-10            7183786.0      85.0  GHCND:USW00023188
# 2  2018-04-10            7183786.0      63.0  GHCND:USW00023272
# 3  2018-04-10            7183786.0      86.0  GHCND:USW00093193
# 4  2018-04-10            7183786.0      68.0  GHCND:USW00093225
# 5  2018-04-10            7183786.0      69.0  GHCND:USW00023293
# 6  2018-04-10            7183786.0      72.0  GHCND:USW00003102
# 7  2018-04-11            6927243.5      74.0  GHCND:USW00023174
# 8  2018-04-11            6927243.5      73.0  GHCND:USW00023188
# 9  2018-04-11            6927243.5      60.0  GHCND:USW00023272
# 10 2018-04-11            6927243.5      75.0  GHCND:USW00093193
# 11 2018-04-11            6927243.5      62.0  GHCND:USW00093225
# 12 2018-04-11            6927243.5      68.0  GHCND:USW00023293
# 13 2018-04-11            6927243.5      82.0  GHCND:USW00003102
# 14 2018-04-12            6670701.0      68.0  GHCND:USW00023174
# 15 2018-04-12            6670701.0      67.0  GHCND:USW00023188
# 16 2018-04-12            6670701.0      57.0  GHCND:USW00023272
# 17 2018-04-12            6670701.0      65.0  GHCND:USW00093193
# 18 2018-04-12            6670701.0      63.0  GHCND:USW00093225
# 19 2018-04-12            6670701.0      62.0  GHCND:USW00023293
#
#                      Station Location  Min Temp        Day
# 0   Los Angeles International Airport      60.0    Tuesday
# 1                   San Diego Airport      60.0    Tuesday
# 2              San Francisco Downtown      52.0    Tuesday
# 3       FRESNO YOSEMITE INTERNATIONAL      59.0    Tuesday
# 4     SACRAMENTO METROPOLITAN AIRPORT      51.0    Tuesday
# 5                            San Jose      52.0    Tuesday
# 6                     Ontario Airport      51.0    Tuesday
# 7   Los Angeles International Airport      57.0  Wednesday
# 8                   San Diego Airport      60.0  Wednesday
# 9              San Francisco Downtown      49.0  Wednesday
# 10      FRESNO YOSEMITE INTERNATIONAL      51.0  Wednesday
# 11    SACRAMENTO METROPOLITAN AIRPORT      44.0  Wednesday
# 12                           San Jose      46.0  Wednesday
# 13                    Ontario Airport      46.0  Wednesday
# 14  Los Angeles International Airport      55.0   Thursday
# 15                  San Diego Airport      59.0   Thursday
# 16             San Francisco Downtown      48.0   Thursday
# 17      FRESNO YOSEMITE INTERNATIONAL      47.0   Thursday
# 18    SACRAMENTO METROPOLITAN AIRPORT      35.0   Thursday
# 19                           San Jose      47.0   Thursday

# %% [markdown]
# Now all of the 4-11-2018 values have been filled in with more realistic energy values.
#
# Figure 2.1 can be replotted now with a better use of whitespace.

# %%
plt.figure(figsize=(18,8))
sns.lineplot(x ='Date', y= 'Daily Energy Demand', data = df) 
plt.title("Fig. 2.1.v2: California's Daily Energy Demand (2018-2022)", fontsize=18)
# Out:
# Text(0.5, 1.0, "Fig. 2.1.v2: California's Daily Energy Demand (2018-2022)")

# %% [markdown]
# #### Feature Engineering- Month

# %% [markdown]
# Creating a feature for month using the month_name function

# %%
df['Month'] = df['Date'].dt.month_name()

# %% [markdown]
# Specifying the month order for plotting

# %%
monthorder= ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']

# %%
plt.figure(figsize=(15,10))
plt.title("Fig. 2.4: California's Monthly Average Energy Demand 2018-2022", fontsize=18)
plt.rc('axes', labelsize=14)
plt.rc('xtick', labelsize=10)
plt.rc('ytick', labelsize=10)
sns.boxplot(data = df, x= 'Month', y='Daily Energy Demand', order= monthorder)
# Out:
# <AxesSubplot:title={'center':"Fig. 2.4: California's Monthly Average Energy Demand 2018-2022"}, xlabel='Month', ylabel='Daily Energy Demand'>

# %% [markdown]
# Unsurprisingly, summer has the most energy demand, likely due to the use of air conditioning. Some outlying data points in May, September and October may be caused by unusually hot days. The increase in December is interesting and while it could be due to weather, could also have additional influences like school being out and Christmas lights.

# %%
df.groupby('Month')['Daily Energy Demand'].describe()
# Out:
#            count          mean            std        min         25%  \
# Month
# April      986.0  6.348322e+06  470803.491624  5242117.0  5941988.00
# August     862.0  8.843393e+06  765236.157840  6905232.0  8319108.00
# December   867.0  6.868896e+06  357114.908015  5893254.0  6533175.50
# February   791.0  6.502349e+06  393163.746612  5642251.0  6254515.00
# January    868.0  6.619063e+06  337553.027087  5810743.0  6353226.25
# July       868.0  8.663328e+06  806243.934794  6790239.0  8152963.25
# June       840.0  7.631256e+06  729738.686928  5756188.0  7106883.25
# March      868.0  6.334860e+06  382226.988398  5350644.0  6040644.75
# May        976.0  6.646605e+06  523458.189719  5564685.0  6255486.00
# November   838.0  6.644518e+06  356414.655247  5834873.0  6284402.50
# October    868.0  7.021411e+06  616420.216821  5721919.0  6587534.00
# September  840.0  8.095429e+06  744201.074471  6138885.0  7671033.50
#
#                  50%         75%         max
# Month
# April      6409634.0  6643068.00   7638350.0
# August     8873114.0  9283218.00  10766451.0
# December   6962293.0  7122762.50   7618952.0
# February   6532427.0  6809994.00   7221650.0
# January    6720612.0  6875809.25   7174229.0
# July       8659204.0  9224283.75  10482535.0
# June       7637678.5  8073755.25   9508169.0
# March      6409806.5  6620303.75   6940731.0
# May        6703187.0  6985824.00   8501267.0
# November   6752980.0  6914207.00   7314240.0
# October    6959322.5  7362312.50   9272495.0
# September  8034100.0  8476995.00  10171423.0

# %% [markdown]
# Quantitative values underlying Figure 2.4

# %% [markdown]
# #### Feature Engineering- Year

# %% [markdown]
# We know that the first and final years in the data set are incomplete, so having the ability to seperate by year may be important. Additionally, it will be interesting to see how demand has changed over the years.

# %%
df['Year']= df['Date'].dt.year

# %%
df.head(2)
# Out:
#         Date  Daily Energy Demand  Max Temp         Station ID  \
# 0 2018-04-10            7183786.0      79.0  GHCND:USW00023174
# 1 2018-04-10            7183786.0      85.0  GHCND:USW00023188
#
#                     Station Location  Min Temp      Day  Month  Year
# 0  Los Angeles International Airport      60.0  Tuesday  April  2018
# 1                  San Diego Airport      60.0  Tuesday  April  2018

# %% [markdown]
# Since both 2018 and 2022 are incomplete, let's first look at a boxplot of the complete years

# %%
plt.figure(figsize=(8,5))
plt.title("Fig. 2.5: California's Yearly Energy Demand", fontsize = 18)
plt.rc('axes', labelsize=14)
plt.rc('xtick', labelsize=10)
plt.rc('ytick', labelsize=10)
full_years = df[(df['Year']== 2019) | (df['Year']== 2020)| (df['Year']== 2021)]          
sns.boxplot(data = full_years, x= 'Year', y='Daily Energy Demand')
# Out:
# <AxesSubplot:title={'center':"Fig. 2.5: California's Yearly Energy Demand"}, xlabel='Year', ylabel='Daily Energy Demand'>

# %% [markdown]
# Both 2020 and 2021 had higher energy demand than 2019. It is notable that despite disruptions caused by COVID-19 in 2020, the energy demand for 2021 is about equal to the demand in 2020.

# %%
plt.figure(figsize=(15,10))
plt.suptitle("Fig. 2.6: California's Energy Demand From 2018-2021", fontsize = 18)
plt.title("Note:2018 is missing data from Jan-March", fontsize = 13)
lineplotdata=df[(df['Year'] != 2022)]
sns.lineplot(data=lineplotdata, x='Month', y='Daily Energy Demand', hue='Year')
# Out:
# <AxesSubplot:title={'center':'Note:2018 is missing data from Jan-March'}, xlabel='Month', ylabel='Daily Energy Demand'>

# %% [markdown]
# Figure 2.6 shows the year-to-year fluctuation in monthly energy demand.
#
# Since it is hard to see the individual monthly fluctuations when plotted this way, let's examine a boxplot of just April.

# %%
plt.figure(figsize=(10,7))
plt.title("Fig. 2.7: CA Energy Demand in April", fontsize = 18)
april_e = df[(df['Month']== 'April')]   
plt.rc('axes', labelsize=14)
plt.rc('xtick', labelsize=10)
plt.rc('ytick', labelsize=10)
sns.boxplot(data = april_e, x= 'Year', y='Daily Energy Demand')
# Out:
# <AxesSubplot:title={'center':'Fig. 2.7: CA Energy Demand in April'}, xlabel='Year', ylabel='Daily Energy Demand'>

# %% [markdown]
# Figure 2.7 highlights the fluctuation between years, especially given the inverse trend observed between this plot and Figure 2.5 which showed 2020 and 2021 as about equal and 2019 as having less energy demand.
#
# Clearly, weather is going to be an important consideration for forcasting energy demand.

# %% [markdown]
# ## Cleaning Weather Data

# %%
df.head()
# Out:
#         Date  Daily Energy Demand  Max Temp         Station ID  \
# 0 2018-04-10            7183786.0      79.0  GHCND:USW00023174
# 1 2018-04-10            7183786.0      85.0  GHCND:USW00023188
# 2 2018-04-10            7183786.0      63.0  GHCND:USW00023272
# 3 2018-04-10            7183786.0      86.0  GHCND:USW00093193
# 4 2018-04-10            7183786.0      68.0  GHCND:USW00093225
#
#                     Station Location  Min Temp      Day  Month  Year
# 0  Los Angeles International Airport      60.0  Tuesday  April  2018
# 1                  San Diego Airport      60.0  Tuesday  April  2018
# 2             San Francisco Downtown      52.0  Tuesday  April  2018
# 3      FRESNO YOSEMITE INTERNATIONAL      59.0  Tuesday  April  2018
# 4    SACRAMENTO METROPOLITAN AIRPORT      51.0  Tuesday  April  2018

# %% [markdown]
# First, let's tidy up the dataframe by giving cleaner names to the station locations

# %%
cleaned_cities = {'Los Angeles International Airport': 'Los Angeles Coastal', 'San Diego Airport': 'San Diego', 'San Francisco Downtown': 'San Francisco', 'FRESNO YOSEMITE INTERNATIONAL': 'Fresno', 
                 'San Jose': 'San Jose', 'Ontario Airport': 'Los Angeles Inland', 'SACRAMENTO METROPOLITAN AIRPORT': 'Sacramento'}

# %%
df['Station Location']= df['Station Location'].map(cleaned_cities)

# %%
df.head()
# Out:
#         Date  Daily Energy Demand  Max Temp         Station ID  \
# 0 2018-04-10            7183786.0      79.0  GHCND:USW00023174
# 1 2018-04-10            7183786.0      85.0  GHCND:USW00023188
# 2 2018-04-10            7183786.0      63.0  GHCND:USW00023272
# 3 2018-04-10            7183786.0      86.0  GHCND:USW00093193
# 4 2018-04-10            7183786.0      68.0  GHCND:USW00093225
#
#       Station Location  Min Temp      Day  Month  Year
# 0  Los Angeles Coastal      60.0  Tuesday  April  2018
# 1            San Diego      60.0  Tuesday  April  2018
# 2        San Francisco      52.0  Tuesday  April  2018
# 3               Fresno      59.0  Tuesday  April  2018
# 4           Sacramento      51.0  Tuesday  April  2018

# %% [markdown]
# In Notebook 1 we found that there were a few instances where temperature data was missing for a station. These aren't null values though, they are just dates where a station did not record its temperature values. This can be verified by:

# %%
df.isna().sum()
# Out:
# Date                   0
# Daily Energy Demand    0
# Max Temp               0
# Station ID             0
# Station Location       0
# Min Temp               0
# Day                    0
# Month                  0
# Year                   0
# dtype: int64

# %% [markdown]
# The dates without temperature measurements from all 7 stations are: 2019-11-18, 2018-02-28, 2022-05-15, 2021-04-23, 2018-08-03, 2018-08-04, 2018-08-05, 2018-08-06, 2018-08-07, 2018-08-08, 2018-12-26, 2019-11-05, 2022-05-16 (see Notebook 1 for how these dates were found).

# %%
# Create a list of dates where at least one value is missing
missing_dates = ['2019-11-18', '2018-02-28', '2022-05-15', '2021-04-23', '2018-08-03', '2018-08-04', '2018-08-05', '2018-08-06', '2018-08-07', '2018-08-08', '2018-12-26', '2019-11-05', '2022-05-16']

# Display more rows than the default values
pd.set_option('display.max_rows', 500)

#Create a dataframe of only the dates with missing temperature data
missingtemps= df[df['Date'].isin(missing_dates)]

# %%
missingtemps['Station Location'].unique()
# Out:
# array(['Los Angeles Coastal', 'San Diego', 'San Francisco', 'Fresno',
#        'Sacramento', 'Los Angeles Inland', 'San Jose', nan], dtype=object)

# %%
missingtemps
# Out:
#                          Date  Daily Energy Demand  Max Temp  \
# 805       2018-08-03 00:00:00            9803690.0      79.0
# 806       2018-08-03 00:00:00            9803690.0      85.0
# 807       2018-08-03 00:00:00            9803690.0      71.0
# 808       2018-08-03 00:00:00            9803690.0     103.0
# 809       2018-08-03 00:00:00            9803690.0      92.0
# 810       2018-08-03 00:00:00            9803690.0      99.0
# 811       2018-08-04 00:00:00            9134719.0      81.0
# 812       2018-08-04 00:00:00            9134719.0      84.0
# 813       2018-08-04 00:00:00            9134719.0      68.0
# 814       2018-08-04 00:00:00            9134719.0     102.0
# 815       2018-08-04 00:00:00            9134719.0      99.0
# 816       2018-08-04 00:00:00            9134719.0     105.0
# 817       2018-08-05 00:00:00            8647165.0      79.0
# 818       2018-08-05 00:00:00            8647165.0      85.0
# 819       2018-08-05 00:00:00            8647165.0      66.0
# 820       2018-08-05 00:00:00            8647165.0      99.0
# 821       2018-08-05 00:00:00            8647165.0      91.0
# 822       2018-08-05 00:00:00            8647165.0     103.0
# 823       2018-08-06 00:00:00            9748326.0      83.0
# 824       2018-08-06 00:00:00            9748326.0      86.0
# 825       2018-08-06 00:00:00            9748326.0      69.0
# 826       2018-08-06 00:00:00            9748326.0      98.0
# 827       2018-08-06 00:00:00            9748326.0      94.0
# 828       2018-08-06 00:00:00            9748326.0      99.0
# 829       2018-08-07 00:00:00            9973567.0      89.0
# 830       2018-08-07 00:00:00            9973567.0      91.0
# 831       2018-08-07 00:00:00            9973567.0      59.0
# 832       2018-08-07 00:00:00            9973567.0      99.0
# 833       2018-08-07 00:00:00            9973567.0      90.0
# 834       2018-08-07 00:00:00            9973567.0     103.0
# 835       2018-08-08 00:00:00            9968893.0      94.0
# 836       2018-08-08 00:00:00            9968893.0      89.0
# 837       2018-08-08 00:00:00            9968893.0      68.0
# 838       2018-08-08 00:00:00            9968893.0     104.0
# 839       2018-08-08 00:00:00            9968893.0      93.0
# 840       2018-08-08 00:00:00            9968893.0      96.0
# 1814      2018-12-26 00:00:00            6605226.0      65.0
# 1815      2018-12-26 00:00:00            6605226.0      65.0
# 1816      2018-12-26 00:00:00            6605226.0      59.0
# 1817      2018-12-26 00:00:00            6605226.0      57.0
# 1818      2018-12-26 00:00:00            6605226.0      57.0
# 1819      2018-12-26 00:00:00            6605226.0      57.0
# 4011      2019-11-05 00:00:00            6937409.0      72.0
# 4012      2019-11-05 00:00:00            6937409.0      71.0
# 4013      2019-11-05 00:00:00            6937409.0      64.0
# 4014      2019-11-05 00:00:00            6937409.0      80.0
# 4015      2019-11-05 00:00:00            6937409.0      67.0
# 4016      2019-11-05 00:00:00            6937409.0      85.0
# 4101      2019-11-18 00:00:00            7010610.0      93.0
# 4102      2019-11-18 00:00:00            7010610.0      91.0
# 4103      2019-11-18 00:00:00            7010610.0      74.0
# 4104      2019-11-18 00:00:00            7010610.0      77.0
# 4105      2019-11-18 00:00:00            7010610.0      67.0
# 4106      2019-11-18 00:00:00            7010610.0      61.0
# 7754      2021-04-23 00:00:00            6565056.0      62.0
# 7755      2021-04-23 00:00:00            6565056.0      64.0
# 7756      2021-04-23 00:00:00            6565056.0      59.0
# 7757      2021-04-23 00:00:00            6565056.0      80.0
# 7758      2021-04-23 00:00:00            6565056.0      60.0
# 7759      2021-04-23 00:00:00            6565056.0      71.0
# 10462     2022-05-15 00:00:00            6435770.0      78.0
# 10463     2022-05-15 00:00:00            6435770.0      70.0
# 10464     2022-05-15 00:00:00            6435770.0      61.0
# 10465     2022-05-15 00:00:00            6435770.0      94.0
# 10466     2022-05-15 00:00:00            6435770.0      92.0
# 10467     2022-05-15 00:00:00            6435770.0      73.0
# 10468     2022-05-16 00:00:00            6824397.0      67.0
# 10469     2022-05-16 00:00:00            6824397.0      67.0
# 10470     2022-05-16 00:00:00            6824397.0      87.0
# 10471     2022-05-16 00:00:00            6824397.0      80.0
# Date_str                  NaN                  NaN       NaN
#
#                  Station ID     Station Location  Min Temp        Day  \
# 805       GHCND:USW00023174  Los Angeles Coastal      69.0     Friday
# 806       GHCND:USW00023188            San Diego      74.0     Friday
# 807       GHCND:USW00023272        San Francisco      53.0     Friday
# 808       GHCND:USW00093193               Fresno      70.0     Friday
# 809       GHCND:USW00093225           Sacramento      53.0     Friday
# 810       GHCND:USW00003102   Los Angeles Inland      68.0     Friday
# 811       GHCND:USW00023174  Los Angeles Coastal      67.0   Saturday
# 812       GHCND:USW00023188            San Diego      73.0   Saturday
# 813       GHCND:USW00023272        San Francisco      55.0   Saturday
# 814       GHCND:USW00093193               Fresno      68.0   Saturday
# 815       GHCND:USW00093225           Sacramento      59.0   Saturday
# 816       GHCND:USW00003102   Los Angeles Inland      70.0   Saturday
# 817       GHCND:USW00023174  Los Angeles Coastal      68.0     Sunday
# 818       GHCND:USW00023188            San Diego      72.0     Sunday
# 819       GHCND:USW00023272        San Francisco      53.0     Sunday
# 820       GHCND:USW00093193               Fresno      67.0     Sunday
# 821       GHCND:USW00093225           Sacramento      61.0     Sunday
# 822       GHCND:USW00003102   Los Angeles Inland      75.0     Sunday
# 823       GHCND:USW00023174  Los Angeles Coastal      68.0     Monday
# 824       GHCND:USW00023188            San Diego      72.0     Monday
# 825       GHCND:USW00023272        San Francisco      51.0     Monday
# 826       GHCND:USW00093193               Fresno      66.0     Monday
# 827       GHCND:USW00093225           Sacramento      59.0     Monday
# 828       GHCND:USW00003102   Los Angeles Inland      72.0     Monday
# 829       GHCND:USW00023174  Los Angeles Coastal      70.0    Tuesday
# 830       GHCND:USW00023188            San Diego      73.0    Tuesday
# 831       GHCND:USW00023272        San Francisco      51.0    Tuesday
# 832       GHCND:USW00093193               Fresno      70.0    Tuesday
# 833       GHCND:USW00093225           Sacramento      58.0    Tuesday
# 834       GHCND:USW00003102   Los Angeles Inland      71.0    Tuesday
# 835       GHCND:USW00023174  Los Angeles Coastal      70.0  Wednesday
# 836       GHCND:USW00023188            San Diego      76.0  Wednesday
# 837       GHCND:USW00023272        San Francisco      53.0  Wednesday
# 838       GHCND:USW00093193               Fresno      69.0  Wednesday
# 839       GHCND:USW00093225           Sacramento      56.0  Wednesday
# 840       GHCND:USW00003102   Los Angeles Inland      75.0  Wednesday
# 1814      GHCND:USW00023174  Los Angeles Coastal      48.0  Wednesday
# 1815      GHCND:USW00023188            San Diego      50.0  Wednesday
# 1816      GHCND:USW00023272        San Francisco      47.0  Wednesday
# 1817      GHCND:USW00093193               Fresno      40.0  Wednesday
# 1818      GHCND:USW00093225           Sacramento      37.0  Wednesday
# 1819      GHCND:USW00003102   Los Angeles Inland      44.0  Wednesday
# 4011      GHCND:USW00023174  Los Angeles Coastal      57.0    Tuesday
# 4012      GHCND:USW00023188            San Diego      50.0    Tuesday
# 4013      GHCND:USW00023272        San Francisco      48.0    Tuesday
# 4014      GHCND:USW00093193               Fresno      46.0    Tuesday
# 4015      GHCND:USW00023293             San Jose      49.0    Tuesday
# 4016      GHCND:USW00003102   Los Angeles Inland      49.0    Tuesday
# 4101      GHCND:USW00023174  Los Angeles Coastal      62.0     Monday
# 4102      GHCND:USW00023188            San Diego      57.0     Monday
# 4103      GHCND:USW00023272        San Francisco      55.0     Monday
# 4104      GHCND:USW00093193               Fresno      48.0     Monday
# 4105      GHCND:USW00023293             San Jose      52.0     Monday
# 4106      GHCND:USW00003102   Los Angeles Inland      50.0     Monday
# 7754      GHCND:USW00023174  Los Angeles Coastal      56.0     Friday
# 7755      GHCND:USW00023188            San Diego      57.0     Friday
# 7756      GHCND:USW00023272        San Francisco      49.0     Friday
# 7757      GHCND:USW00093193               Fresno      50.0     Friday
# 7758      GHCND:USW00023293             San Jose      46.0     Friday
# 7759      GHCND:USW00003102   Los Angeles Inland      53.0     Friday
# 10462     GHCND:USW00023174  Los Angeles Coastal      59.0     Sunday
# 10463     GHCND:USW00023188            San Diego      59.0     Sunday
# 10464     GHCND:USW00023272        San Francisco      51.0     Sunday
# 10465     GHCND:USW00093193               Fresno      65.0     Sunday
# 10466     GHCND:USW00093225           Sacramento      57.0     Sunday
# 10467     GHCND:USW00003102   Los Angeles Inland      42.0     Sunday
# 10468     GHCND:USW00023174  Los Angeles Coastal      59.0     Monday
# 10469     GHCND:USW00023188            San Diego      58.0     Monday
# 10470     GHCND:USW00093193               Fresno      59.0     Monday
# 10471     GHCND:USW00003102   Los Angeles Inland      49.0     Monday
# Date_str                NaN                  NaN       NaN        NaN
#
#              Month    Year    Date_str
# 805         August  2018.0  2018-08-03
# 806         August  2018.0  2018-08-03
# 807         August  2018.0  2018-08-03
# 808         August  2018.0  2018-08-03
# 809         August  2018.0  2018-08-03
# 810         August  2018.0  2018-08-03
# 811         August  2018.0  2018-08-04
# 812         August  2018.0  2018-08-04
# 813         August  2018.0  2018-08-04
# 814         August  2018.0  2018-08-04
# 815         August  2018.0  2018-08-04
# 816         August  2018.0  2018-08-04
# 817         August  2018.0  2018-08-05
# 818         August  2018.0  2018-08-05
# 819         August  2018.0  2018-08-05
# 820         August  2018.0  2018-08-05
# 821         August  2018.0  2018-08-05
# 822         August  2018.0  2018-08-05
# 823         August  2018.0  2018-08-06
# 824         August  2018.0  2018-08-06
# 825         August  2018.0  2018-08-06
# 826         August  2018.0  2018-08-06
# 827         August  2018.0  2018-08-06
# 828         August  2018.0  2018-08-06
# 829         August  2018.0  2018-08-07
# 830         August  2018.0  2018-08-07
# 831         August  2018.0  2018-08-07
# 832         August  2018.0  2018-08-07
# 833         August  2018.0  2018-08-07
# 834         August  2018.0  2018-08-07
# 835         August  2018.0  2018-08-08
# 836         August  2018.0  2018-08-08
# 837         August  2018.0  2018-08-08
# 838         August  2018.0  2018-08-08
# 839         August  2018.0  2018-08-08
# 840         August  2018.0  2018-08-08
# 1814      December  2018.0  2018-12-26
# 1815      December  2018.0  2018-12-26
# 1816      December  2018.0  2018-12-26
# 1817      December  2018.0  2018-12-26
# 1818      December  2018.0  2018-12-26
# 1819      December  2018.0  2018-12-26
# 4011      November  2019.0  2019-11-05
# 4012      November  2019.0  2019-11-05
# 4013      November  2019.0  2019-11-05
# 4014      November  2019.0  2019-11-05
# 4015      November  2019.0  2019-11-05
# 4016      November  2019.0  2019-11-05
# 4101      November  2019.0  2019-11-18
# 4102      November  2019.0  2019-11-18
# 4103      November  2019.0  2019-11-18
# 4104      November  2019.0  2019-11-18
# 4105      November  2019.0  2019-11-18
# 4106      November  2019.0  2019-11-18
# 7754         April  2021.0  2021-04-23
# 7755         April  2021.0  2021-04-23
# 7756         April  2021.0  2021-04-23
# 7757         April  2021.0  2021-04-23
# 7758         April  2021.0  2021-04-23
# 7759         April  2021.0  2021-04-23
# 10462          May  2022.0  2022-05-15
# 10463          May  2022.0  2022-05-15
# 10464          May  2022.0  2022-05-15
# 10465          May  2022.0  2022-05-15
# 10466          May  2022.0  2022-05-15
# 10467          May  2022.0  2022-05-15
# 10468          May  2022.0  2022-05-16
# 10469          May  2022.0  2022-05-16
# 10470          May  2022.0  2022-05-16
# 10471          May  2022.0  2022-05-16
# Date_str       NaN     NaN         nan

# %%
missingtemps_small= pd.DataFrame(columns=['Los Angeles Coastal', 'San Diego', 'San Francisco', 'Fresno',
       'Sacramento', 'Los Angeles Inland', 'San Jose'], index=missing_dates)

# %%
if missingtemps['Station Location'] == Los Angeles Coastal.isna()

# %%
missingtemps_small
# Out:
#            Los Angeles Coastal San Diego San Francisco Fresno Sacramento  \
# 2019-11-18                 NaN       NaN           NaN    NaN        NaN
# 2018-02-28                 NaN       NaN           NaN    NaN        NaN
# 2022-05-15                 NaN       NaN           NaN    NaN        NaN
# 2021-04-23                 NaN       NaN           NaN    NaN        NaN
# 2018-08-03                 NaN       NaN           NaN    NaN        NaN
# 2018-08-04                 NaN       NaN           NaN    NaN        NaN
# 2018-08-05                 NaN       NaN           NaN    NaN        NaN
# 2018-08-06                 NaN       NaN           NaN    NaN        NaN
# 2018-08-07                 NaN       NaN           NaN    NaN        NaN
# 2018-08-08                 NaN       NaN           NaN    NaN        NaN
# 2018-12-26                 NaN       NaN           NaN    NaN        NaN
# 2019-11-05                 NaN       NaN           NaN    NaN        NaN
# 2022-05-16                 NaN       NaN           NaN    NaN        NaN
#
#            Los Angeles Inland San Jose
# 2019-11-18                NaN      NaN
# 2018-02-28                NaN      NaN
# 2022-05-15                NaN      NaN
# 2021-04-23                NaN      NaN
# 2018-08-03                NaN      NaN
# 2018-08-04                NaN      NaN
# 2018-08-05                NaN      NaN
# 2018-08-06                NaN      NaN
# 2018-08-07                NaN      NaN
# 2018-08-08                NaN      NaN
# 2018-12-26                NaN      NaN
# 2019-11-05                NaN      NaN
# 2022-05-16                NaN      NaN

# %%
pd.reset_option('display.max_rows')

# %%
def date_as_str(date):
    date_str = str(date)[0:10]
    return date_str

# %%
missingtemps['Date_str'] = missingtemps['Date'].apply(date_as_str)
# df['Daily Energy Demand']= testdf.apply(missingdata_fill, axis=1)
# Out:
# C:\Users\18053\AppData\Local\Temp\ipykernel_564\791926531.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   missingtemps['Date_str'] = missingtemps['Date'].apply(date_as_str)

# %%
missingtemps
# Out:
#             Date  Daily Energy Demand  Max Temp         Station ID  \
# 805   2018-08-03            9803690.0      79.0  GHCND:USW00023174
# 806   2018-08-03            9803690.0      85.0  GHCND:USW00023188
# 807   2018-08-03            9803690.0      71.0  GHCND:USW00023272
# 808   2018-08-03            9803690.0     103.0  GHCND:USW00093193
# 809   2018-08-03            9803690.0      92.0  GHCND:USW00093225
# 810   2018-08-03            9803690.0      99.0  GHCND:USW00003102
# 811   2018-08-04            9134719.0      81.0  GHCND:USW00023174
# 812   2018-08-04            9134719.0      84.0  GHCND:USW00023188
# 813   2018-08-04            9134719.0      68.0  GHCND:USW00023272
# 814   2018-08-04            9134719.0     102.0  GHCND:USW00093193
# 815   2018-08-04            9134719.0      99.0  GHCND:USW00093225
# 816   2018-08-04            9134719.0     105.0  GHCND:USW00003102
# 817   2018-08-05            8647165.0      79.0  GHCND:USW00023174
# 818   2018-08-05            8647165.0      85.0  GHCND:USW00023188
# 819   2018-08-05            8647165.0      66.0  GHCND:USW00023272
# 820   2018-08-05            8647165.0      99.0  GHCND:USW00093193
# 821   2018-08-05            8647165.0      91.0  GHCND:USW00093225
# 822   2018-08-05            8647165.0     103.0  GHCND:USW00003102
# 823   2018-08-06            9748326.0      83.0  GHCND:USW00023174
# 824   2018-08-06            9748326.0      86.0  GHCND:USW00023188
# 825   2018-08-06            9748326.0      69.0  GHCND:USW00023272
# 826   2018-08-06            9748326.0      98.0  GHCND:USW00093193
# 827   2018-08-06            9748326.0      94.0  GHCND:USW00093225
# 828   2018-08-06            9748326.0      99.0  GHCND:USW00003102
# 829   2018-08-07            9973567.0      89.0  GHCND:USW00023174
# 830   2018-08-07            9973567.0      91.0  GHCND:USW00023188
# 831   2018-08-07            9973567.0      59.0  GHCND:USW00023272
# 832   2018-08-07            9973567.0      99.0  GHCND:USW00093193
# 833   2018-08-07            9973567.0      90.0  GHCND:USW00093225
# 834   2018-08-07            9973567.0     103.0  GHCND:USW00003102
# 835   2018-08-08            9968893.0      94.0  GHCND:USW00023174
# 836   2018-08-08            9968893.0      89.0  GHCND:USW00023188
# 837   2018-08-08            9968893.0      68.0  GHCND:USW00023272
# 838   2018-08-08            9968893.0     104.0  GHCND:USW00093193
# 839   2018-08-08            9968893.0      93.0  GHCND:USW00093225
# 840   2018-08-08            9968893.0      96.0  GHCND:USW00003102
# 1814  2018-12-26            6605226.0      65.0  GHCND:USW00023174
# 1815  2018-12-26            6605226.0      65.0  GHCND:USW00023188
# 1816  2018-12-26            6605226.0      59.0  GHCND:USW00023272
# 1817  2018-12-26            6605226.0      57.0  GHCND:USW00093193
# 1818  2018-12-26            6605226.0      57.0  GHCND:USW00093225
# 1819  2018-12-26            6605226.0      57.0  GHCND:USW00003102
# 4011  2019-11-05            6937409.0      72.0  GHCND:USW00023174
# 4012  2019-11-05            6937409.0      71.0  GHCND:USW00023188
# 4013  2019-11-05            6937409.0      64.0  GHCND:USW00023272
# 4014  2019-11-05            6937409.0      80.0  GHCND:USW00093193
# 4015  2019-11-05            6937409.0      67.0  GHCND:USW00023293
# 4016  2019-11-05            6937409.0      85.0  GHCND:USW00003102
# 4101  2019-11-18            7010610.0      93.0  GHCND:USW00023174
# 4102  2019-11-18            7010610.0      91.0  GHCND:USW00023188
# 4103  2019-11-18            7010610.0      74.0  GHCND:USW00023272
# 4104  2019-11-18            7010610.0      77.0  GHCND:USW00093193
# 4105  2019-11-18            7010610.0      67.0  GHCND:USW00023293
# 4106  2019-11-18            7010610.0      61.0  GHCND:USW00003102
# 7754  2021-04-23            6565056.0      62.0  GHCND:USW00023174
# 7755  2021-04-23            6565056.0      64.0  GHCND:USW00023188
# 7756  2021-04-23            6565056.0      59.0  GHCND:USW00023272
# 7757  2021-04-23            6565056.0      80.0  GHCND:USW00093193
# 7758  2021-04-23            6565056.0      60.0  GHCND:USW00023293
# 7759  2021-04-23            6565056.0      71.0  GHCND:USW00003102
# 10462 2022-05-15            6435770.0      78.0  GHCND:USW00023174
# 10463 2022-05-15            6435770.0      70.0  GHCND:USW00023188
# 10464 2022-05-15            6435770.0      61.0  GHCND:USW00023272
# 10465 2022-05-15            6435770.0      94.0  GHCND:USW00093193
# 10466 2022-05-15            6435770.0      92.0  GHCND:USW00093225
# 10467 2022-05-15            6435770.0      73.0  GHCND:USW00003102
# 10468 2022-05-16            6824397.0      67.0  GHCND:USW00023174
# 10469 2022-05-16            6824397.0      67.0  GHCND:USW00023188
# 10470 2022-05-16            6824397.0      87.0  GHCND:USW00093193
# 10471 2022-05-16            6824397.0      80.0  GHCND:USW00003102
#
#           Station Location  Min Temp        Day     Month  Year    Date_str
# 805    Los Angeles Coastal      69.0     Friday    August  2018  2018-08-03
# 806              San Diego      74.0     Friday    August  2018  2018-08-03
# 807          San Francisco      53.0     Friday    August  2018  2018-08-03
# 808                 Fresno      70.0     Friday    August  2018  2018-08-03
# 809             Sacramento      53.0     Friday    August  2018  2018-08-03
# 810     Los Angeles Inland      68.0     Friday    August  2018  2018-08-03
# 811    Los Angeles Coastal      67.0   Saturday    August  2018  2018-08-04
# 812              San Diego      73.0   Saturday    August  2018  2018-08-04
# 813          San Francisco      55.0   Saturday    August  2018  2018-08-04
# 814                 Fresno      68.0   Saturday    August  2018  2018-08-04
# 815             Sacramento      59.0   Saturday    August  2018  2018-08-04
# 816     Los Angeles Inland      70.0   Saturday    August  2018  2018-08-04
# 817    Los Angeles Coastal      68.0     Sunday    August  2018  2018-08-05
# 818              San Diego      72.0     Sunday    August  2018  2018-08-05
# 819          San Francisco      53.0     Sunday    August  2018  2018-08-05
# 820                 Fresno      67.0     Sunday    August  2018  2018-08-05
# 821             Sacramento      61.0     Sunday    August  2018  2018-08-05
# 822     Los Angeles Inland      75.0     Sunday    August  2018  2018-08-05
# 823    Los Angeles Coastal      68.0     Monday    August  2018  2018-08-06
# 824              San Diego      72.0     Monday    August  2018  2018-08-06
# 825          San Francisco      51.0     Monday    August  2018  2018-08-06
# 826                 Fresno      66.0     Monday    August  2018  2018-08-06
# 827             Sacramento      59.0     Monday    August  2018  2018-08-06
# 828     Los Angeles Inland      72.0     Monday    August  2018  2018-08-06
# 829    Los Angeles Coastal      70.0    Tuesday    August  2018  2018-08-07
# 830              San Diego      73.0    Tuesday    August  2018  2018-08-07
# 831          San Francisco      51.0    Tuesday    August  2018  2018-08-07
# 832                 Fresno      70.0    Tuesday    August  2018  2018-08-07
# 833             Sacramento      58.0    Tuesday    August  2018  2018-08-07
# 834     Los Angeles Inland      71.0    Tuesday    August  2018  2018-08-07
# 835    Los Angeles Coastal      70.0  Wednesday    August  2018  2018-08-08
# 836              San Diego      76.0  Wednesday    August  2018  2018-08-08
# 837          San Francisco      53.0  Wednesday    August  2018  2018-08-08
# 838                 Fresno      69.0  Wednesday    August  2018  2018-08-08
# 839             Sacramento      56.0  Wednesday    August  2018  2018-08-08
# 840     Los Angeles Inland      75.0  Wednesday    August  2018  2018-08-08
# 1814   Los Angeles Coastal      48.0  Wednesday  December  2018  2018-12-26
# 1815             San Diego      50.0  Wednesday  December  2018  2018-12-26
# 1816         San Francisco      47.0  Wednesday  December  2018  2018-12-26
# 1817                Fresno      40.0  Wednesday  December  2018  2018-12-26
# 1818            Sacramento      37.0  Wednesday  December  2018  2018-12-26
# 1819    Los Angeles Inland      44.0  Wednesday  December  2018  2018-12-26
# 4011   Los Angeles Coastal      57.0    Tuesday  November  2019  2019-11-05
# 4012             San Diego      50.0    Tuesday  November  2019  2019-11-05
# 4013         San Francisco      48.0    Tuesday  November  2019  2019-11-05
# 4014                Fresno      46.0    Tuesday  November  2019  2019-11-05
# 4015              San Jose      49.0    Tuesday  November  2019  2019-11-05
# 4016    Los Angeles Inland      49.0    Tuesday  November  2019  2019-11-05
# 4101   Los Angeles Coastal      62.0     Monday  November  2019  2019-11-18
# 4102             San Diego      57.0     Monday  November  2019  2019-11-18
# 4103         San Francisco      55.0     Monday  November  2019  2019-11-18
# 4104                Fresno      48.0     Monday  November  2019  2019-11-18
# 4105              San Jose      52.0     Monday  November  2019  2019-11-18
# 4106    Los Angeles Inland      50.0     Monday  November  2019  2019-11-18
# 7754   Los Angeles Coastal      56.0     Friday     April  2021  2021-04-23
# 7755             San Diego      57.0     Friday     April  2021  2021-04-23
# 7756         San Francisco      49.0     Friday     April  2021  2021-04-23
# 7757                Fresno      50.0     Friday     April  2021  2021-04-23
# 7758              San Jose      46.0     Friday     April  2021  2021-04-23
# 7759    Los Angeles Inland      53.0     Friday     April  2021  2021-04-23
# 10462  Los Angeles Coastal      59.0     Sunday       May  2022  2022-05-15
# 10463            San Diego      59.0     Sunday       May  2022  2022-05-15
# 10464        San Francisco      51.0     Sunday       May  2022  2022-05-15
# 10465               Fresno      65.0     Sunday       May  2022  2022-05-15
# 10466           Sacramento      57.0     Sunday       May  2022  2022-05-15
# 10467   Los Angeles Inland      42.0     Sunday       May  2022  2022-05-15
# 10468  Los Angeles Coastal      59.0     Monday       May  2022  2022-05-16
# 10469            San Diego      58.0     Monday       May  2022  2022-05-16
# 10470               Fresno      59.0     Monday       May  2022  2022-05-16
# 10471   Los Angeles Inland      49.0     Monday       May  2022  2022-05-16

# %%
sns.heatmap(train.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %%
fig = plt.figure(1, figsize=(20,5))
ax = fig.add_subplot()
sns.scatterplot(data = missingtemps, y='Station Location', x='Date_str', palette='rainbow', ax = ax)
ax.set_xticks(missing_dates, labels=missing_dates)
ax.set_xticklabels(missing_dates)
# Out:
# [Text(8.0, 0, '2019-11-18'),
#  Text(12.0, 0, '2018-02-28'),
#  Text(10.0, 0, '2022-05-15'),
#  Text(9.0, 0, '2021-04-23'),
#  Text(0.0, 0, '2018-08-03'),
#  Text(1.0, 0, '2018-08-04'),
#  Text(2.0, 0, '2018-08-05'),
#  Text(3.0, 0, '2018-08-06'),
#  Text(4.0, 0, '2018-08-07'),
#  Text(5.0, 0, '2018-08-08'),
#  Text(6.0, 0, '2018-12-26'),
#  Text(7.0, 0, '2019-11-05'),
#  Text(11.0, 0, '2022-05-16')]
